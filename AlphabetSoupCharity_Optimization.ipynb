# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd 
application_df = pd.read_csv("https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv")
application_df.head(20)
# Out:
#          EIN                                               NAME  \
# 0   10520599                       BLUE KNIGHTS MOTORCYCLE CLUB
# 1   10531628             AMERICAN CHESAPEAKE CLUB CHARITABLE TR
# 2   10547893                 ST CLOUD PROFESSIONAL FIREFIGHTERS
# 3   10553066                     SOUTHSIDE ATHLETIC ASSOCIATION
# 4   10556103           GENETIC RESEARCH INSTITUTE OF THE DESERT
# 5   10556855  MINORITY ORGAN & TISSUE TRANSPLANT & EDUCATION...
# 6   10558440  FRIENDS OF ARTS COUNCIL OF GREATER DENHAM SPRI...
# 7   10566033                          ISRAEL EMERGENCY ALLIANCE
# 8   10570430                                   ARAMCO BRATS INC
# 9   10571689         INTERNATIONAL ASSOCIATION OF FIRE FIGHTERS
# 10  10573059                      KAI ELUA OUTRIGGER CANOE CLUB
# 11  10575727                                   HERITAGE ACADEMY
# 12  10583569                   THE UNITED STATES PONY CLUBS INC
# 13  10585206  DOMINION INTERNATIONAL NETWORK OF MINISTRIES &...
# ...

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
application_df_drop = application_df.drop(['EIN', 'NAME'], axis=1)

# %%
# Determine the number of unique values in each column.
unique_counts = application_df_drop.nunique()
print(unique_counts)
# Out:
# APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning
application_counts = application_df_drop['APPLICATION_TYPE'].value_counts()
print(application_counts)
# Out:
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: APPLICATION_TYPE, dtype: int64

# %%
application_counts = application_df_drop['APPLICATION_TYPE'].value_counts()

# Choose a cutoff value and create a list of application types to be replaced use the variable name `application_types_to_replace`
cutoff_value = 527


application_types_to_replace = application_counts[application_counts <= cutoff_value].index.tolist()

# Replace in dataframe
for app_type in application_types_to_replace:
    application_df_drop['APPLICATION_TYPE'] = application_df_drop['APPLICATION_TYPE'].replace(app_type, 'Other')

# Check to make sure binning was successful
application_df_drop['APPLICATION_TYPE'].value_counts()
# Out:
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
classification_counts = application_df_drop['CLASSIFICATION'].value_counts()
print(classification_counts)
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C8210        1
# C2561        1
# C4500        1
# C2150        1
# Name: CLASSIFICATION, Length: 71, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
classification_counts = application_df_drop['CLASSIFICATION'].value_counts()
classification_counts_filtered = classification_counts[classification_counts > 1]
print(classification_counts_filtered)
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C7200       32
# C2300       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C1800       15
# C6000       15
# C1250       14
# C8200       11
# C1238       10
# C1278       10
# C1235        9
# C1237        9
# C7210        7
# C2400        6
# C1720        6
# C4100        6
# C1257        5
# C1600        5
# C1260        3
# C2710        3
# C0           3
# C3200        2
# C1234        2
# C1246        2
# C1267        2
# C1256        2
# Name: CLASSIFICATION, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced use the variable name `classifications_to_replace`
cutoff_value = 1882  # Choose the cutoff value

classification_counts = application_df_drop['CLASSIFICATION'].value_counts()
classifications_to_replace = classification_counts[classification_counts <= cutoff_value].index.tolist()

# Replace in dataframe
for cls in classifications_to_replace:
    application_df_drop['CLASSIFICATION'] = application_df_drop['CLASSIFICATION'].replace(cls,"Other")
    
# Check to make sure binning was successful
application_df_drop['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# Other     2261
# C3000     1918
# C2100     1883
# Name: CLASSIFICATION, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
# Identify the categorical columns
categorical_columns = ['APPLICATION_TYPE', 'AFFILIATION', 'CLASSIFICATION', 'USE_CASE', 'ORGANIZATION', 'STATUS', 'INCOME_AMT', 'SPECIAL_CONSIDERATIONS']

# Convert categorical columns to dummy variables
dummy_df = pd.get_dummies(application_df_drop[categorical_columns])

# Concatenate the dummy variables with the original DataFrame
application_df_numeric = pd.concat([application_df_drop, dummy_df], axis=1)

# Drop the original categorical columns if desired
application_df_numeric = application_df_numeric.drop(categorical_columns, axis=1)

# %%
# Split our preprocessed data into our features and target arrays
X = application_df_numeric.drop('IS_SUCCESSFUL', axis=1)
y = application_df_numeric['IS_SUCCESSFUL']

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
import numpy as np

# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
number_input_features = X_train_scaled.shape[1]
hidden_nodes_layer1 =  800
hidden_nodes_layer2 = 300
hidden_nodes_layer3 = 100

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation="LeakyReLU"))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation="LeakyReLU"))

# Third hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer3, activation="LeakyReLU"))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 800)               34400
#
#  dense_1 (Dense)             (None, 300)               240300
#
#  dense_2 (Dense)             (None, 100)               30100
#
#  dense_3 (Dense)             (None, 1)                 101
#
# ...
# Total params: 304,901
# Trainable params: 304,901
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
fit_model = nn.fit(X_train_scaled,y_train,epochs=110)
# Out:
# Epoch 1/110
# 804/804 [==============================] - 10s 10ms/step - loss: 0.5766 - accuracy: 0.7205
# Epoch 2/110
# 804/804 [==============================] - 6s 8ms/step - loss: 0.5624 - accuracy: 0.7278
# Epoch 3/110
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5591 - accuracy: 0.7292
# Epoch 4/110
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5569 - accuracy: 0.7311
# Epoch 5/110
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5556 - accuracy: 0.7284
# Epoch 6/110
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5542 - accuracy: 0.7308
# Epoch 7/110
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5529 - accuracy: 0.7324
# Epoch 8/110
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5537 - accuracy: 0.7310
# Epoch 9/110
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5534 - accuracy: 0.7320
# Epoch 10/110
# ...

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
# Out:
# 268/268 - 1s - loss: 0.5519 - accuracy: 0.7265 - 614ms/epoch - 2ms/step

# %%
# Export our model to HDF5 file
AlphabetSoupCharity_Optimization = "AlphabetSoupCharity_Optimization.h5"
nn.save(AlphabetSoupCharity_Optimization)
print(f"Model saved to {AlphabetSoupCharity_Optimization}")
# Out:
# Model saved to AlphabetSoupCharity_Optimization.h5
